# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show
output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e76798f9-fbc7-4e94-9c28-ff999e265769">Loading BokehJS ...</span>
#     </div>

# %%
from seismicio import readsu
sudata = readsu('/volume1/Downloads/marmousi_CS_ep1.su')
traces = sudata.traces
# Out:
# Number of samples: 1445
# Number of traces: 96

# %%
from wiggle_bokeh import wiggle

# %%
myplot = wiggle(traces)

show(myplot)
# Out:
#   <div id="c2cbdbea-4a97-42c2-9eff-446562ac03a3" data-root-id="p1001" style="display: contents;"></div>
