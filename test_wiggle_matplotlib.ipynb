# %%
import numpy as np
import matplotlib.pyplot as plt
from seismicio import readsu
from wiggle import wiggle

# %%
sudata = readsu('/volume1/Downloads/marmousi_CS_ep1.su')
traces = sudata.traces
# Out:
# Number of samples: 1445
# Number of traces: 96

# %%
from wiggle_matplotlib import wiggle

# %%
wiggle(traces, stretch_factor=0.15)
